# %% [markdown]
# # Einführung in neuronale Netze mit Keras
#
# In diesem Notebook wird die Keras API vorgestellt und ein kleines neuronales Netzwerk trainiert. Dokumentation und weitere Tutorials gibt es auf https://keras.io/.

# %%
import os
import tarfile
import urllib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras

pd.options.mode.chained_assignment = None  # default='warn'
sns.set_context("talk")

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"


def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()


fetch_housing_data()

# %%
housing_data = pd.read_csv("./datasets/housing/housing.csv")
housing_data.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
images_path = os.path.join("./", "images")
os.makedirs(images_path, exist_ok=True)
filename = "california.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/end_to_end_project/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))
# Out:
# Downloading california.png
# ('./images/california.png', <http.client.HTTPMessage at 0x7fd2fd7d4820>)

# %%
import matplotlib.image as mpimg

california_img = mpimg.imread(os.path.join(images_path, filename))
ax = housing_data.plot(
    kind="scatter",
    x="longitude",
    y="latitude",
    figsize=(10, 7),
    s=housing_data["population"] / 100,
    label="Population",
    c="median_house_value",
    cmap=plt.get_cmap("jet"),
    colorbar=False,
    alpha=0.4,
)
plt.imshow(
    california_img,
    extent=[-124.55, -113.80, 32.45, 42.05],
    alpha=0.5,
    cmap=plt.get_cmap("jet"),
)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing_data["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values / prices.max())
cbar.ax.set_yticklabels(["$%dk" % (round(v / 1000)) for v in tick_values], fontsize=14)
cbar.set_label("Median House Value", fontsize=16)

plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # prepare data

# %%
sns.heatmap(housing_data.notna())
# Out:
# <AxesSubplot:>

# %%
housing_data = housing_data.dropna()

# %% [markdown]
# # Training a single Neuron with the Keras API

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models

X = housing_data.drop(
    columns=["median_house_value", "ocean_proximity", ]
)
y = housing_data["median_house_value"].copy()
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

X_train = scaler.fit_transform(X_train)
y_train = y_train.values

X_test = scaler.transform(X_test)
y_test = y_test.values

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income
# 0       322.0       126.0         8.3252
# 1      2401.0      1138.0         8.3014
# 2       496.0       177.0         7.2574
# 3       558.0       219.0         5.6431
# 4       565.0       259.0         3.8462

# %%
X_train.shape  # (samples/instances, features)
# Out:
# (14303, 8)

# %%
neuron_model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],), name="Input"),
    keras.layers.Dense(1, activation="linear", name="Neuron")
])

# %% [markdown]
# ## Woher kommen die 9 Parameter?

# %%
neuron_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Neuron (Dense)               (None, 1)                 9
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install pydot
keras.utils.plot_model(neuron_model, "single_neuron.png")
# Out:
# Requirement already satisfied: pydot in /home/mago1/anaconda3/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/mago1/anaconda3/lib/python3.8/site-packages (from pydot) (2.4.7)

# %%
neuron_model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=5e-4),
    loss=keras.losses.MeanSquaredError(),
    metrics=keras.losses.MeanAbsoluteError(),
)

# %%
history = neuron_model.fit(
    x=X_train, y=y_train, batch_size=64, epochs=30, validation_split=0.3
)
# Out:
# Epoch 1/30
# 157/157 [==============================] - 1s 3ms/step - loss: 53497268923.9494 - mean_absolute_error: 201529.6883 - val_loss: 42179649536.0000 - val_mean_absolute_error: 174286.6094
# Epoch 2/30
# 157/157 [==============================] - 0s 912us/step - loss: 40171389653.8734 - mean_absolute_error: 171483.3906 - val_loss: 32440094720.0000 - val_mean_absolute_error: 148611.2656
# Epoch 3/30
# 157/157 [==============================] - 0s 952us/step - loss: 30862627256.7089 - mean_absolute_error: 145138.5179 - val_loss: 25334020096.0000 - val_mean_absolute_error: 126806.2031
# Epoch 4/30
# 157/157 [==============================] - 0s 906us/step - loss: 23834844134.0760 - mean_absolute_error: 124826.6565 - val_loss: 20143900672.0000 - val_mean_absolute_error: 108669.8281
# Epoch 5/30
# 157/157 [==============================] - 0s 835us/step - loss: 19352715017.7215 - mean_absolute_error: 107936.8197 - val_loss: 16353102848.0000 - val_mean_absolute_error: 94203.6953
# Epoch 6/30
# 157/157 [==============================] - 0s 869us/step - loss: 16269982609.8228 - mean_absolute_error: 95800.8830 - val_loss: 13579727872.0000 - val_mean_absolute_error: 83145.1797
# Epoch 7/30
# 157/157 [==============================] - 0s 884us/step - loss: 13037687231.1899 - mean_absolute_error: 82569.7585 - val_loss: 11545374720.0000 - val_mean_absolute_error: 74976.5234
# Epoch 8/30
# 157/157 [==============================] - 0s 825us/step - loss: 11141541580.1519 - mean_absolute_error: 74568.3747 - val_loss: 10052177920.0000 - val_mean_absolute_error: 68931.0391
# Epoch 9/30
# 157/157 [==============================] - 0s 811us/step - loss: 9505924633.9241 - mean_absolute_error: 67773.6730 - val_loss: 8954272768.0000 - val_mean_absolute_error: 64597.1016
# Epoch 10/30
# 157/157 [==============================] - 0s 856us/step - loss: 8284456033.2152 - mean_absolute_error: 63083.4408 - val_loss: 8145462272.0000 - val_mean_absolute_error: 61540.1172
# Epoch 11/30
# 157/157 [==============================] - 0s 927us/step - loss: 7826496147.4430 - mean_absolute_error: 60915.5208 - val_loss: 7546667008.0000 - val_mean_absolute_error: 59432.3320
# Epoch 12/30
# 157/157 [==============================] - 0s 929us/step - loss: 7173193627.5443 - mean_absolute_error: 59132.4407 - val_loss: 7102901248.0000 - val_mean_absolute_error: 57979.6484
# Epoch 13/30
# 157/157 [==============================] - 0s 892us/step - loss: 7207096054.2785 - mean_absolute_error: 59218.7115 - val_loss: 6773146624.0000 - val_mean_absolute_error: 57013.6914
# Epoch 14/30
# 157/157 [==============================] - 0s 932us/step - loss: 6508736220.3544 - mean_absolute_error: 56835.4849 - val_loss: 6525107200.0000 - val_mean_absolute_error: 56397.3672
# Epoch 15/30
# 157/157 [==============================] - 0s 819us/step - loss: 6281624815.7975 - mean_absolute_error: 55718.6897 - val_loss: 6336926208.0000 - val_mean_absolute_error: 56006.7148
# Epoch 16/30
# 157/157 [==============================] - 0s 848us/step - loss: 6105705128.5063 - mean_absolute_error: 55308.1997 - val_loss: 6192650752.0000 - val_mean_absolute_error: 55734.1562
# Epoch 17/30
# 157/157 [==============================] - 0s 815us/step - loss: 6113413087.5949 - mean_absolute_error: 56212.2739 - val_loss: 6082012160.0000 - val_mean_absolute_error: 55566.1016
# Epoch 18/30
# 157/157 [==============================] - 0s 731us/step - loss: 5934968611.6456 - mean_absolute_error: 55093.2092 - val_loss: 5994797568.0000 - val_mean_absolute_error: 55456.9922
# Epoch 19/30
# 157/157 [==============================] - 0s 741us/step - loss: 5768731654.4810 - mean_absolute_error: 54742.3815 - val_loss: 5925454336.0000 - val_mean_absolute_error: 55384.3789
# Epoch 20/30
# 157/157 [==============================] - 0s 822us/step - loss: 5966310928.2025 - mean_absolute_error: 55506.6350 - val_loss: 5869751296.0000 - val_mean_absolute_error: 55346.6641
# Epoch 21/30
# 157/157 [==============================] - 0s 816us/step - loss: 5843561055.5949 - mean_absolute_error: 55044.6020 - val_loss: 5824111616.0000 - val_mean_absolute_error: 55325.8906
# Epoch 22/30
# 157/157 [==============================] - 0s 876us/step - loss: 5596713624.3038 - mean_absolute_error: 54397.1263 - val_loss: 5785446912.0000 - val_mean_absolute_error: 55304.5938
# Epoch 23/30
# 157/157 [==============================] - 0s 847us/step - loss: 5708539161.9241 - mean_absolute_error: 55130.2980 - val_loss: 5752237568.0000 - val_mean_absolute_error: 55278.2031
# Epoch 24/30
# 157/157 [==============================] - 0s 855us/step - loss: 5410070761.3165 - mean_absolute_error: 53343.5692 - val_loss: 5723731456.0000 - val_mean_absolute_error: 55250.6992
# Epoch 25/30
# 157/157 [==============================] - 0s 874us/step - loss: 5637543077.2658 - mean_absolute_error: 54740.8429 - val_loss: 5697696256.0000 - val_mean_absolute_error: 55214.3203
# Epoch 26/30
# 157/157 [==============================] - 0s 803us/step - loss: 5464541461.0633 - mean_absolute_error: 54025.0365 - val_loss: 5674863616.0000 - val_mean_absolute_error: 55176.3242
# Epoch 27/30
# 157/157 [==============================] - 0s 758us/step - loss: 5590102323.8481 - mean_absolute_error: 54599.4047 - val_loss: 5653447168.0000 - val_mean_absolute_error: 55132.1836
# Epoch 28/30
# 157/157 [==============================] - 0s 765us/step - loss: 5511826146.8354 - mean_absolute_error: 54766.3615 - val_loss: 5633714176.0000 - val_mean_absolute_error: 55082.4375
# Epoch 29/30
# 157/157 [==============================] - 0s 811us/step - loss: 5567504231.6962 - mean_absolute_error: 55145.5418 - val_loss: 5615319552.0000 - val_mean_absolute_error: 55028.6602
# Epoch 30/30
# 157/157 [==============================] - 0s 884us/step - loss: 5414831873.6203 - mean_absolute_error: 54052.8799 - val_loss: 5598712832.0000 - val_mean_absolute_error: 54973.3125

# %%
print(history.history.keys())
plt.figure(figsize=(14, 4))
series = history.history["mean_absolute_error"]
plt.plot(range(len(series)), series, label="mean_absolute_error")
series = history.history["val_mean_absolute_error"]
plt.plot(range(len(series)), series, label="val_mean_absolute_error")
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
neuron_model.evaluate(X_train, y_train)
# Out:
# 447/447 [==============================] - 0s 416us/step - loss: 5472602624.0000 - mean_absolute_error: 54398.2461
# [5472602624.0, 54398.24609375]

# %%
neuron_model.evaluate(X_test, y_test)
# Out:
# 192/192 [==============================] - 0s 476us/step - loss: 5630603264.0000 - mean_absolute_error: 55067.8008
# [5630603264.0, 55067.80078125]

# %% [markdown]
# ## Training a small Network with the Keras API

# %%
from sklearn.preprocessing import StandardScaler

from tensorflow.keras import layers, models

# %%
X_train.shape
# Out:
# (14303, 8)

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential

network = Sequential(
    [
        Dense(10, input_shape = [X_train.shape[1]], activation="relu"),
        Dense(10,activation="relu"),
        Dense(1, activation="linear"),
    ]
)
network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                90
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
network.compile(
    optimizer=keras.optimizers.SGD(learning_rate=5e-4),
#     optimizer='nadam',
    loss=tf.keras.losses.MeanAbsoluteError(),
    metrics=[tf.keras.metrics.MeanAbsoluteError()],
)

# %%
history = network.fit(x=X_train, y=y_train, batch_size=32, epochs=25, validation_split=0.3)
# Out:
# Epoch 1/25
# 313/313 [==============================] - 1s 1ms/step - loss: 209721.4472 - mean_absolute_error: 209721.4472 - val_loss: 205205.6562 - val_mean_absolute_error: 205205.6562
# Epoch 2/25
# 313/313 [==============================] - 0s 990us/step - loss: 208119.0216 - mean_absolute_error: 208119.0216 - val_loss: 205205.2344 - val_mean_absolute_error: 205205.2344
# Epoch 3/25
# 313/313 [==============================] - 0s 899us/step - loss: 208261.2261 - mean_absolute_error: 208261.2261 - val_loss: 205204.7188 - val_mean_absolute_error: 205204.7188
# Epoch 4/25
# 313/313 [==============================] - 0s 874us/step - loss: 207374.1319 - mean_absolute_error: 207374.1319 - val_loss: 205204.1562 - val_mean_absolute_error: 205204.1562
# Epoch 5/25
# 313/313 [==============================] - 0s 916us/step - loss: 208709.5946 - mean_absolute_error: 208709.5946 - val_loss: 205203.2344 - val_mean_absolute_error: 205203.2344
# Epoch 6/25
# 313/313 [==============================] - 0s 894us/step - loss: 209183.9923 - mean_absolute_error: 209183.9923 - val_loss: 205201.7500 - val_mean_absolute_error: 205201.7500
# Epoch 7/25
# 313/313 [==============================] - 0s 840us/step - loss: 209732.9425 - mean_absolute_error: 209732.9425 - val_loss: 205198.7031 - val_mean_absolute_error: 205198.7031
# Epoch 8/25
# 313/313 [==============================] - 0s 838us/step - loss: 210347.8212 - mean_absolute_error: 210347.8212 - val_loss: 205191.4844 - val_mean_absolute_error: 205191.4844
# Epoch 9/25
# 313/313 [==============================] - 0s 880us/step - loss: 210315.2143 - mean_absolute_error: 210315.2143 - val_loss: 205166.1875 - val_mean_absolute_error: 205166.1875
# Epoch 10/25
# 313/313 [==============================] - 0s 849us/step - loss: 208628.1963 - mean_absolute_error: 208628.1963 - val_loss: 204967.4375 - val_mean_absolute_error: 204967.4375
# Epoch 11/25
# 313/313 [==============================] - 0s 869us/step - loss: 207292.1948 - mean_absolute_error: 207292.1948 - val_loss: 95181.2031 - val_mean_absolute_error: 95181.2031
# Epoch 12/25
# 313/313 [==============================] - 0s 879us/step - loss: 60939.1699 - mean_absolute_error: 60939.1699 - val_loss: 49316.6367 - val_mean_absolute_error: 49316.6367
# Epoch 13/25
# 313/313 [==============================] - 0s 904us/step - loss: 47788.3991 - mean_absolute_error: 47788.3991 - val_loss: 48141.8828 - val_mean_absolute_error: 48141.8828
# Epoch 14/25
# 313/313 [==============================] - 0s 862us/step - loss: 47033.8227 - mean_absolute_error: 47033.8227 - val_loss: 47160.3125 - val_mean_absolute_error: 47160.3125
# Epoch 15/25
# 313/313 [==============================] - 0s 835us/step - loss: 47459.0136 - mean_absolute_error: 47459.0136 - val_loss: 46427.1562 - val_mean_absolute_error: 46427.1562
# Epoch 16/25
# 313/313 [==============================] - 0s 866us/step - loss: 46079.9444 - mean_absolute_error: 46079.9444 - val_loss: 46434.0312 - val_mean_absolute_error: 46434.0312
# Epoch 17/25
# 313/313 [==============================] - 0s 874us/step - loss: 46128.8100 - mean_absolute_error: 46128.8100 - val_loss: 45648.3555 - val_mean_absolute_error: 45648.3555
# Epoch 18/25
# 313/313 [==============================] - 0s 865us/step - loss: 45915.9736 - mean_absolute_error: 45915.9736 - val_loss: 45319.3359 - val_mean_absolute_error: 45319.3359
# Epoch 19/25
# 313/313 [==============================] - 0s 927us/step - loss: 45398.8799 - mean_absolute_error: 45398.8799 - val_loss: 45655.5820 - val_mean_absolute_error: 45655.5820
# Epoch 20/25
# 313/313 [==============================] - 0s 868us/step - loss: 44756.6705 - mean_absolute_error: 44756.6705 - val_loss: 45508.5898 - val_mean_absolute_error: 45508.5898
# Epoch 21/25
# 313/313 [==============================] - 0s 862us/step - loss: 45158.5697 - mean_absolute_error: 45158.5697 - val_loss: 44695.3750 - val_mean_absolute_error: 44695.3750
# Epoch 22/25
# 313/313 [==============================] - 0s 906us/step - loss: 44917.5088 - mean_absolute_error: 44917.5088 - val_loss: 45935.6953 - val_mean_absolute_error: 45935.6953
# Epoch 23/25
# 313/313 [==============================] - 0s 883us/step - loss: 43995.7421 - mean_absolute_error: 43995.7421 - val_loss: 44605.6602 - val_mean_absolute_error: 44605.6602
# Epoch 24/25
# 313/313 [==============================] - 0s 875us/step - loss: 44470.2565 - mean_absolute_error: 44470.2565 - val_loss: 44818.8633 - val_mean_absolute_error: 44818.8633
# Epoch 25/25
# 313/313 [==============================] - 0s 865us/step - loss: 45054.4790 - mean_absolute_error: 45054.4790 - val_loss: 45887.0430 - val_mean_absolute_error: 45887.0430

# %%
print(history.history.keys())
plt.figure(figsize=(14, 4))
series = history.history["mean_absolute_error"]
plt.plot(range(len(series)), series, label="mean_absolute_error")
series = history.history["val_mean_absolute_error"]
plt.plot(range(len(series)), series, label="val_mean_absolute_error")
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
network.evaluate(X_train, y_train)
# Out:
# 447/447 [==============================] - 0s 509us/step - loss: 45488.2891 - mean_absolute_error: 45488.2891
# [45488.2890625, 45488.2890625]

# %%
network.evaluate(X_test,y_test)
# Out:
# 192/192 [==============================] - 0s 486us/step - loss: 45611.8867 - mean_absolute_error: 45611.8867
# [45611.88671875, 45611.88671875]

# %% [markdown]
# ## Übung:
#
# * Verwende den Code von oben und trainiere das Modell mit Mean-Absolute-Error loss und probiere andere Netzwerk Architekturen aus (mehr Layer, mehr Neuronen usw)
#     * keras.losses.MeanAbsoluteError()
#
# * Probiere verschiedene Aktivierungsfunktionen für die Neurone. Was ändert sich am Verlauf des Losses?
#     * Für eine Liste von Aktivierungsfunktionen siehe https://keras.io/api/layers/activations/#available-activations

# %% [markdown]
# ## Zusatzübung:
#
# * Skaliere die Zielvariable, so dass die Größenordnung ~1. Verbessert sich dadurch die Performance des Modells?

# %% [markdown]
# # Zusatzübung 2:
#
# Die folgenden Daten wurden vorbereitet:
#
# Aufgabe:
#
# * Trainiere ein neuronales Netzwerk welches MPG vorhersagt
# * Teste die Performance dem Testdatensatz (80%:20% split)
#
# Hinweis: Dies geht mit "model.evaluate(test_features, test_labels)"

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(
    url, names=column_names,
    na_values='?', comment='\t',
    sep=' ', skipinitialspace=True
)
dataset = raw_dataset.copy().drop(columns=["Origin"])
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %%
dataset = dataset.dropna()
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

pd.plotting.scatter_matrix(
    dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], 
    figsize=(10, 10), marker='o', 
    hist_kwds={'bins': 20},
    s=60, 
    alpha=.4
)
plt.show()

# %%
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
test_labels = test_features.pop('MPG')
